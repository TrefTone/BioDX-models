# %% [markdown]
# # Import Liberies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/kidney_disease.csv')

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (400, 26)

# %%
df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# std     79.281714   50.503006    5.741126   10.408752    3.193904    2.912587
# min     22.000000    1.500000    0.400000    4.500000    2.500000    3.100000
# 25%     99.000000   27.000000    0.900000  135.000000    3.800000   10.300000
# 50%    121.000000   42.000000    1.300000  138.000000    4.400000   12.650000
# 75%    163.000000   66.000000    2.800000  142.000000    4.900000   15.000000
# max    490.000000  391.000000   76.000000  163.000000   47.000000   17.800000

# %%
df.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
col={'age': 'age',
     'bp': 'blood_pressure',
     'sg': 'specific_gravity',
     'al': 'albumin',
     'su': 'sugar',
     'rbc': 'red_blood_cells',
     'pc': 'pus_cell',
     'pcc': 'pus_cell_clumps',
     'ba': 'bacteria',
     'bgr': 'blood_glucose_random',
     'bu': 'blood_urea',
     'sc': 'serum_creatinine',
     'sod': 'sodium',
     'pot': 'potassium',
     'hemo': 'hemoglobin',
     'pcv': 'packed_cell_volume',
     'wc': 'white_blood_cell_count',
     'rc': 'red_blood_cell_count',
     'htn': 'hypertension',
     'dm': 'diabetes_mellitus',
     'cad': 'coronary_artery_disease',
     'appet': 'appetite',
     'pe': 'pedal_edema',
     'ane': 'anemia',
     'classification': 'class'}
df.rename(columns=col, inplace=True)
df
# Out:
#       id   age  blood_pressure  specific_gravity  albumin  sugar  \
# 0      0  48.0            80.0             1.020      1.0    0.0
# 1      1   7.0            50.0             1.020      4.0    0.0
# 2      2  62.0            80.0             1.010      2.0    3.0
# 3      3  48.0            70.0             1.005      4.0    0.0
# 4      4  51.0            80.0             1.010      2.0    0.0
# ..   ...   ...             ...               ...      ...    ...
# 395  395  55.0            80.0             1.020      0.0    0.0
# 396  396  42.0            70.0             1.025      0.0    0.0
# 397  397  12.0            80.0             1.020      0.0    0.0
# 398  398  17.0            60.0             1.025      0.0    0.0
# 399  399  58.0            80.0             1.025      0.0    0.0
#
#     red_blood_cells  pus_cell pus_cell_clumps    bacteria  ...  \
# 0               NaN    normal      notpresent  notpresent  ...
# 1               NaN    normal      notpresent  notpresent  ...
# 2            normal    normal      notpresent  notpresent  ...
# 3            normal  abnormal         present  notpresent  ...
# 4            normal    normal      notpresent  notpresent  ...
# ..              ...       ...             ...         ...  ...
# 395          normal    normal      notpresent  notpresent  ...
# 396          normal    normal      notpresent  notpresent  ...
# 397          normal    normal      notpresent  notpresent  ...
# 398          normal    normal      notpresent  notpresent  ...
# 399          normal    normal      notpresent  notpresent  ...
#
#      packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# 0                    44                    7800                   5.2
# 1                    38                    6000                   NaN
# 2                    31                    7500                   NaN
# 3                    32                    6700                   3.9
# 4                    35                    7300                   4.6
# ..                  ...                     ...                   ...
# 395                  47                    6700                   4.9
# 396                  54                    7800                   6.2
# 397                  49                    6600                   5.4
# 398                  51                    7200                   5.9
# 399                  53                    6800                   6.1
#
#      hypertension  diabetes_mellitus  coronary_artery_disease appetite  \
# 0             yes                yes                       no     good
# 1              no                 no                       no     good
# 2              no                yes                       no     poor
# 3             yes                 no                       no     poor
# 4              no                 no                       no     good
# ..            ...                ...                      ...      ...
# 395            no                 no                       no     good
# 396            no                 no                       no     good
# 397            no                 no                       no     good
# 398            no                 no                       no     good
# 399            no                 no                       no     good
#
#     pedal_edema anemia   class
# 0            no     no     ckd
# 1            no     no     ckd
# 2            no    yes     ckd
# 3           yes    yes     ckd
# 4            no     no     ckd
# ..          ...    ...     ...
# 395          no     no  notckd
# 396          no     no  notckd
# 397          no     no  notckd
# 398          no     no  notckd
# 399          no     no  notckd
#
# [400 rows x 26 columns]

# %%
# converting necessary columns to numerical type

df['packed_cell_volume'] = pd.to_numeric(df['packed_cell_volume'],errors='coerce')
df['white_blood_cell_count'] = pd.to_numeric(df['white_blood_cell_count'],errors='coerce')
df['red_blood_cell_count'] = pd.to_numeric(df['red_blood_cell_count'],errors='coerce')

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       400 non-null    int64
#  1   age                      391 non-null    float64
#  2   blood_pressure           388 non-null    float64
#  3   specific_gravity         353 non-null    float64
#  4   albumin                  354 non-null    float64
#  5   sugar                    351 non-null    float64
#  6   red_blood_cells          248 non-null    object
#  7   pus_cell                 335 non-null    object
#  8   pus_cell_clumps          396 non-null    object
#  9   bacteria                 396 non-null    object
#  10  blood_glucose_random     356 non-null    float64
#  11  blood_urea               381 non-null    float64
#  12  serum_creatinine         383 non-null    float64
#  13  sodium                   313 non-null    float64
#  14  potassium                312 non-null    float64
#  15  hemoglobin               348 non-null    float64
#  16  packed_cell_volume       329 non-null    float64
#  17  white_blood_cell_count   294 non-null    float64
#  18  red_blood_cell_count     269 non-null    float64
#  19  hypertension             398 non-null    object
#  20  diabetes_mellitus        398 non-null    object
#  21  coronary_artery_disease  398 non-null    object
#  22  appetite                 399 non-null    object
#  23  pedal_edema              399 non-null    object
#  24  anemia                   399 non-null    object
#  25  class                    400 non-null    object
# dtypes: float64(14), int64(1), object(11)
# memory usage: 81.4+ KB

# %%
# Categorical and numerical columns

cat_cols = [col for col in df.columns if df[col].dtype == 'object']
num_cols = [col for col in df.columns if df[col].dtype != 'object']

# %%
#Unique values of categorical columns
for col in cat_cols:
    unique_values = df[col].unique()
    print(f"Unique values in column '{col}':")
    print(unique_values)
    print("\n"+"="*60+"\n")
# Out:
# Unique values in column 'red_blood_cells':
# [nan 'normal' 'abnormal']
#
# ============================================================
#
# Unique values in column 'pus_cell':
# ['normal' 'abnormal' nan]
#
# ============================================================
#
# Unique values in column 'pus_cell_clumps':
# ['notpresent' 'present' nan]
#
# ============================================================
#
# Unique values in column 'bacteria':
# ['notpresent' 'present' nan]
#
# ============================================================
#
# Unique values in column 'hypertension':
# ['yes' 'no' nan]
#
# ============================================================
#
# Unique values in column 'diabetes_mellitus':
# ['yes' 'no' ' yes' '\tno' '\tyes' nan]
#
# ============================================================
#
# Unique values in column 'coronary_artery_disease':
# ['no' 'yes' '\tno' nan]
#
# ============================================================
#
# Unique values in column 'appetite':
# ['good' 'poor' nan]
#
# ============================================================
#
# Unique values in column 'pedal_edema':
# ['no' 'yes' nan]
#
# ============================================================
#
# Unique values in column 'anemia':
# ['no' 'yes' nan]
#
# ============================================================
#
# Unique values in column 'class':
# ['ckd' 'ckd\t' 'notckd']
#
# ============================================================

# %%
#replace weird values
df['diabetes_mellitus']=df['diabetes_mellitus'].replace({'\tno':'no','\tyes':'yes',' yes':'yes'})
df['coronary_artery_disease']=df['coronary_artery_disease'].replace('\tno','no')
df['class']=df['class'].replace('ckd\t','ckd' )

# %%
#Unique values of categorical columns
for col in cat_cols:
    unique_values = df[col].unique()
    print(f"Unique values in column '{col}':")
    print(unique_values)
    print("\n"+"="*60+"\n")
# Out:
# Unique values in column 'red_blood_cells':
# [nan 'normal' 'abnormal']
#
# ============================================================
#
# Unique values in column 'pus_cell':
# ['normal' 'abnormal' nan]
#
# ============================================================
#
# Unique values in column 'pus_cell_clumps':
# ['notpresent' 'present' nan]
#
# ============================================================
#
# Unique values in column 'bacteria':
# ['notpresent' 'present' nan]
#
# ============================================================
#
# Unique values in column 'hypertension':
# ['yes' 'no' nan]
#
# ============================================================
#
# Unique values in column 'diabetes_mellitus':
# ['yes' 'no' nan]
#
# ============================================================
#
# Unique values in column 'coronary_artery_disease':
# ['no' 'yes' nan]
#
# ============================================================
#
# Unique values in column 'appetite':
# ['good' 'poor' nan]
#
# ============================================================
#
# Unique values in column 'pedal_edema':
# ['no' 'yes' nan]
#
# ============================================================
#
# Unique values in column 'anemia':
# ['no' 'yes' nan]
#
# ============================================================
#
# Unique values in column 'class':
# ['ckd' 'notckd']
#
# ============================================================

# %%
#plot displot for num_cols
for col in num_cols:
    plt.figure(figsize= (8,5))
    sns.displot(df[col],kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Density')
    plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(8,5))
    plt.title(f'Count plot of {col}')
    sns.countplot(x=df[col],palette='rocket')
    plt.xlabel(col)
    plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(8,5))
    plt.title(f'Count plot of {col}')
    sns.countplot(x=col,hue='class', data= df,palette='rocket')
    plt.xlabel(col)
    plt.show()

# %%
plt.figure(figsize = (15, 8))

sns.heatmap(df[num_cols].corr(), annot = True, linewidths = 2, linecolor = 'lightgrey')
plt.show()

# %% [markdown]
# # Preprocessing

# %%
# checking for null values

df.isna().sum().sort_values(ascending = False)
# Out:
# red_blood_cells            152
# red_blood_cell_count       131
# white_blood_cell_count     106
# potassium                   88
# sodium                      87
# packed_cell_volume          71
# pus_cell                    65
# hemoglobin                  52
# sugar                       49
# specific_gravity            47
# albumin                     46
# blood_glucose_random        44
# blood_urea                  19
# serum_creatinine            17
# blood_pressure              12
# age                          9
# pus_cell_clumps              4
# bacteria                     4
# diabetes_mellitus            2
# hypertension                 2
# coronary_artery_disease      2
# appetite                     1
# anemia                       1
# pedal_edema                  1
# id                           0
# class                        0
# dtype: int64

# %%
def random_value_imputation(feature):
    random_sample = df[feature].dropna().sample(df[feature].isna().sum())
    random_sample.index = df[df[feature].isnull()].index
    df.loc[df[feature].isnull(), feature] = random_sample

def impute_mode(feature):
    mode = df[feature].mode()[0]
    df[feature] = df[feature].fillna(mode)

# %%
# filling num_cols null values using random sampling method

for col in num_cols:
    random_value_imputation(col)

# %%
# filling "red_blood_cells" and "pus_cell" using random sampling method and rest of cat_cols using mode imputation

random_value_imputation('red_blood_cells')
random_value_imputation('pus_cell')

for col in cat_cols:
    impute_mode(col)

# %%
# checking for null values

df.isna().sum().sort_values(ascending = False)
# Out:
# id                         0
# age                        0
# blood_pressure             0
# specific_gravity           0
# albumin                    0
# sugar                      0
# red_blood_cells            0
# pus_cell                   0
# pus_cell_clumps            0
# bacteria                   0
# blood_glucose_random       0
# blood_urea                 0
# serum_creatinine           0
# sodium                     0
# potassium                  0
# hemoglobin                 0
# packed_cell_volume         0
# white_blood_cell_count     0
# red_blood_cell_count       0
# hypertension               0
# diabetes_mellitus          0
# coronary_artery_disease    0
# appetite                   0
# pedal_edema                0
# anemia                     0
# class                      0
# dtype: int64

# %%
for col in cat_cols:
    print (f"{col} has {df[col].nunique()} categories\n")
# Out:
# red_blood_cells has 2 categories
#
# pus_cell has 2 categories
#
# pus_cell_clumps has 2 categories
#
# bacteria has 2 categories
#
# hypertension has 2 categories
#
# diabetes_mellitus has 2 categories
#
# coronary_artery_disease has 2 categories
#
# appetite has 2 categories
#
# pedal_edema has 2 categories
#
# anemia has 2 categories
#
# class has 2 categories

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
for col in cat_cols:
    df[col]=l.fit_transform(df[col])

# %%
df.head()
# Out:
#    id   age  blood_pressure  specific_gravity  albumin  sugar  \
# 0   0  48.0            80.0             1.020      1.0    0.0
# 1   1   7.0            50.0             1.020      4.0    0.0
# 2   2  62.0            80.0             1.010      2.0    3.0
# 3   3  48.0            70.0             1.005      4.0    0.0
# 4   4  51.0            80.0             1.010      2.0    0.0
#
#    red_blood_cells  pus_cell  pus_cell_clumps  bacteria  ...  \
# 0                1         1                0         0  ...
# 1                1         1                0         0  ...
# 2                1         1                0         0  ...
# 3                1         0                1         0  ...
# 4                1         1                0         0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# 0                44.0                  7800.0                   5.2
# 1                38.0                  6000.0                   4.5
# 2                31.0                  7500.0                   4.7
# 3                32.0                  6700.0                   3.9
# 4                35.0                  7300.0                   4.6
#
#    hypertension  diabetes_mellitus  coronary_artery_disease  appetite  \
# 0             1                  1                        0         0
# 1             0                  0                        0         0
# 2             0                  1                        0         1
# 3             1                  0                        0         1
# 4             0                  0                        0         0
#
#    pedal_edema  anemia  class
# 0            0       0      0
# 1            0       0      0
# 2            0       1      0
# 3            1       1      0
# 4            0       0      0
#
# [5 rows x 26 columns]

# %%
#split data in X and Y
x = df.drop(['class', 'id'], axis=1)  # feature variables
y = df['class']  # target variable

# %% [markdown]
# # splitting data

# %%
# splitting data intp training and test set

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# Split again after scaling
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.30, random_state=0)

# %%
# Reshape after split
X_train_reshaped = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_reshaped = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)


# Convert y to numpy array (optional, in case it's a Series)
y_train = y_train.values
y_test = y_test.values

# Import required layers and callbacks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, Dropout, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf

# %% [markdown]
# ## CNN

# %%
from tensorflow.keras.regularizers import l2

# Define CNN model with more dropout & L2 regularization
cnn_model = Sequential([
    Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1), kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.4),
    Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.4),
    Flatten(),
    Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

cnn_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0003),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

# Early stopping with stricter patience
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train CNN model
history_cnn = cnn_model.fit(X_train_reshaped, y_train, epochs=30, batch_size=32,
                            validation_data=(X_test_reshaped, y_test),
                            callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5550 - loss: 1.0248 - val_accuracy: 0.8833 - val_loss: 0.7311
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7589 - loss: 0.7310 - val_accuracy: 0.9167 - val_loss: 0.6946
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7561 - loss: 0.6934 - val_accuracy: 0.9500 - val_loss: 0.6683
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7926 - loss: 0.4950 - val_accuracy: 0.9583 - val_loss: 0.6471
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8268 - loss: 0.4928 - val_accuracy: 0.9583 - val_loss: 0.6314
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8972 - loss: 0.3271 - val_accuracy: 0.9583 - val_loss: 0.6156
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9005 - loss: 0.3258 - val_accuracy: 0.9667 - val_loss: 0.5983
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9071 - loss: 0.3773 - val_accuracy: 0.9583 - val_loss: 0.5825
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8817 - loss: 0.3821 - val_accuracy: 0.9167 - val_loss: 0.5746
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9285 - loss: 0.3010 - val_accuracy: 0.9083 - val_loss: 0.5614
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9257 - loss: 0.2888 - val_accuracy: 0.8750 - val_loss: 0.5496
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9309 - loss: 0.2788 - val_accuracy: 0.8750 - val_loss: 0.5356
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9083 - loss: 0.3473 - val_accuracy: 0.8500 - val_loss: 0.5233
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9451 - loss: 0.2611 - val_accuracy: 0.8917 - val_loss: 0.5001
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9340 - loss: 0.2495 - val_accuracy: 0.8750 - val_loss: 0.4859
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9227 - loss: 0.2933 - val_accuracy: 0.9000 - val_loss: 0.4703
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9290 - loss: 0.2648 - val_accuracy: 0.9083 - val_loss: 0.4498
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9233 - loss: 0.2944 - val_accuracy: 0.9167 - val_loss: 0.4381
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9651 - loss: 0.2096 - val_accuracy: 0.9167 - val_loss: 0.4267
# Epoch 20/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9584 - loss: 0.2449 - val_accuracy: 0.9417 - val_loss: 0.4009
# Epoch 21/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9595 - loss: 0.2223 - val_accuracy: 0.9750 - val_loss: 0.3709
# Epoch 22/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9497 - loss: 0.2203 - val_accuracy: 0.9750 - val_loss: 0.3513
# Epoch 23/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9494 - loss: 0.2192 - val_accuracy: 0.9583 - val_loss: 0.3524
# Epoch 24/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9459 - loss: 0.2706 - val_accuracy: 0.9583 - val_loss: 0.3443
# Epoch 25/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9650 - loss: 0.2041 - val_accuracy: 0.9667 - val_loss: 0.3220
# Epoch 26/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9522 - loss: 0.2218 - val_accuracy: 0.9750 - val_loss: 0.3062
# Epoch 27/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9746 - loss: 0.1739 - val_accuracy: 0.9750 - val_loss: 0.2980
# Epoch 28/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9565 - loss: 0.2161 - val_accuracy: 0.9750 - val_loss: 0.2974
# Epoch 29/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9447 - loss: 0.2833 - val_accuracy: 0.9750 - val_loss: 0.2678
# Epoch 30/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9413 - loss: 0.2284 - val_accuracy: 0.9833 - val_loss: 0.2556

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history_cnn.history['accuracy'], label='Train Accuracy')
plt.plot(history_cnn.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history_cnn.history['loss'], label='Train Loss')
plt.plot(history_cnn.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# ## ANN

# %%
from tensorflow.keras.layers import LeakyReLU
from sklearn.preprocessing import StandardScaler

# Feature Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define ANN model with fixes
ann_model = Sequential([
    Dense(128, kernel_initializer='he_normal'),
    LeakyReLU(alpha=0.1),
    Dropout(0.4),

    Dense(64, kernel_initializer='he_normal'),
    LeakyReLU(alpha=0.1),
    Dropout(0.3),

    Dense(32, kernel_initializer='he_normal'),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(1, activation='sigmoid')
])

# Compile model with lower learning rate
ann_model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

# Early stopping
early_stopping_ann = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train ANN model
history_ann = ann_model.fit(X_train_scaled, y_train, epochs=50, batch_size=32,
                            validation_data=(X_test_scaled, y_test),
                            callbacks=[early_stopping_ann])
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.6877 - loss: 0.5807 - val_accuracy: 0.7500 - val_loss: 0.4026
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7376 - loss: 0.4911 - val_accuracy: 0.8583 - val_loss: 0.3739
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7005 - loss: 0.5211 - val_accuracy: 0.9333 - val_loss: 0.3489
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7796 - loss: 0.4260 - val_accuracy: 0.9500 - val_loss: 0.3283
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7994 - loss: 0.4059 - val_accuracy: 0.9500 - val_loss: 0.3104
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8057 - loss: 0.4047 - val_accuracy: 0.9500 - val_loss: 0.2945
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8283 - loss: 0.3726 - val_accuracy: 0.9500 - val_loss: 0.2808
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7840 - loss: 0.3984 - val_accuracy: 0.9500 - val_loss: 0.2670
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8559 - loss: 0.3512 - val_accuracy: 0.9500 - val_loss: 0.2554
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8725 - loss: 0.3026 - val_accuracy: 0.9500 - val_loss: 0.2443
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8489 - loss: 0.3458 - val_accuracy: 0.9583 - val_loss: 0.2333
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8786 - loss: 0.2719 - val_accuracy: 0.9583 - val_loss: 0.2236
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8761 - loss: 0.2943 - val_accuracy: 0.9583 - val_loss: 0.2146
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9146 - loss: 0.2531 - val_accuracy: 0.9583 - val_loss: 0.2069
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8368 - loss: 0.3434 - val_accuracy: 0.9583 - val_loss: 0.2001
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8857 - loss: 0.2728 - val_accuracy: 0.9583 - val_loss: 0.1934
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8878 - loss: 0.2979 - val_accuracy: 0.9583 - val_loss: 0.1869
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9346 - loss: 0.2520 - val_accuracy: 0.9583 - val_loss: 0.1812
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8912 - loss: 0.2541 - val_accuracy: 0.9583 - val_loss: 0.1757
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9129 - loss: 0.1904 - val_accuracy: 0.8083 - val_loss: 0.3461
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9363 - loss: 0.1729 - val_accuracy: 0.8083 - val_loss: 0.3398
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9281 - loss: 0.2078 - val_accuracy: 0.8250 - val_loss: 0.3194
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9410 - loss: 0.1470 - val_accuracy: 0.8833 - val_loss: 0.2720
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9569 - loss: 0.1353 - val_accuracy: 0.6917 - val_loss: 0.4219
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9411 - loss: 0.1612 - val_accuracy: 0.8750 - val_loss: 0.2941
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9517 - loss: 0.1293 - val_accuracy: 0.9500 - val_loss: 0.2070
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9469 - loss: 0.1573 - val_accuracy: 0.9500 - val_loss: 0.2122
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9363 - loss: 0.1758 - val_accuracy: 0.8333 - val_loss: 0.2947
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9503 - loss: 0.1216 - val_accuracy: 0.9000 - val_loss: 0.2703
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9350 - loss: 0.1403 - val_accuracy: 0.9417 - val_loss: 0.2024
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9510 - loss: 0.1981 - val_accuracy: 0.9000 - val_loss: 0.2476
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9512 - loss: 0.1127 - val_accuracy: 0.9250 - val_loss: 0.2281

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history_lstm.history['accuracy'], label='Train Accuracy')
plt.plot(history_lstm.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy (LSTM)')
plt.legend()

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history_lstm.history['loss'], label='Train Loss')
plt.plot(history_lstm.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss (LSTM)')
plt.legend()

plt.show()

# %% [markdown]
# ## XGBOOST

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# Feature Scaling (already done above)
X_train_xgb = X_train_scaled  # No reshaping needed for XGBoost
X_test_xgb = X_test_scaled

# Initialize XGBoost Model
xgb_model = XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=6, random_state=42)

# Train Model
xgb_model.fit(X_train_xgb, y_train)

# Predictions
y_pred_xgb = xgb_model.predict(X_test_xgb)

# Accuracy
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
print(f"XGBoost Accuracy: {accuracy_xgb:.4f}")
# Out:
# XGBoost Accuracy: 0.9500

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Generate confusion matrix
cm_xgb = confusion_matrix(y_test, y_pred_xgb)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm_xgb)
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix (XGBoost)')
plt.show()

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Initialize and train Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict
y_pred_rf = rf_model.predict(X_test)

# Accuracy
rf_accuracy = accuracy_score(y_test, y_pred_rf)
print(f"Random Forest Accuracy: {rf_accuracy:.4f}")
# Out:
# Random Forest Accuracy: 0.9583

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Generate confusion matrix
cm_rf = confusion_matrix(y_test, y_pred_rf)

# Plot confusion matrix
disp_rf = ConfusionMatrixDisplay(confusion_matrix=cm_rf)
disp_rf.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix (Random Forest)')
plt.show()

# %% [markdown]
# # Model Comparison

# %%
import matplotlib.pyplot as plt

# Store accuracies
model_names = ["LSTM", "CNN", "ANN", "XGBoost", "Random Forest"]
accuracies = [lstm_model.evaluate(X_test_lstm, y_test, verbose=0)[1],
              cnn_model.evaluate(X_test_reshaped, y_test, verbose=0)[1],
              history_ann.history['val_accuracy'][-1],
              accuracy_xgb,
              rf_accuracy]

# Bar plot
plt.figure(figsize=(8, 5))
plt.bar(model_names, accuracies, color=['blue', 'red', 'orange', 'green', 'purple'])
plt.ylim(0.5, 1)
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.title("Model Accuracy Comparison")
plt.show()

# %%
# Save as CSV
import os
import joblib
import tensorflow as tf

# 🎯 Folder create karo jisme models store honge
os.makedirs("models", exist_ok=True)

# 🔹 LSTM Model Save
lstm_model.save("models/lstm_model.h5")

# 🔹 CNN Model Save
cnn_model.save("models/cnn_model.h5")

# 🔹 ANN Model Save
ann_model.save("models/ann_model.h5")

# 🔹 XGBoost Model Save
joblib.dump(xgb_model, "models/xgboost_model.pkl")

# 🔹 Random Forest Model Save
joblib.dump(rf_model, "models/random_forest_model.pkl")

# ✅ Ab ZIP bana lo
# !zip -r models.zip models
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#   adding: models/ (stored 0%)
#   adding: models/ann_model.h5 (deflated 23%)
#   adding: models/cnn_model.h5 (deflated 15%)
#   adding: models/random_forest_model.pkl (deflated 83%)
#   adding: models/lstm_model.h5 (deflated 18%)
#   adding: models/xgboost_model.pkl (deflated 84%)
